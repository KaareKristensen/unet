# %%
from model import *
from data import *
import tensorflow as tf

# %% [markdown]
# # Check that transfer learning loads the correct weights

# %%
model = UNet(pretrained_weights="small_augment_unet_CHASEDB1.hdf5", input_size=(608, 576, 1))
model.save("small_augment_unet_CHASEDB1_named_layers.hdf5")

# %%
transferModel = UNet(pretrained_weights="temp.hdf5", input_size=(608, 576, 1), transfer_learn=True, kernel_initializer = initializers.Constant(0.))
print(np.array_equal(model.get_weights(), transferModel.get_weights()))
print()
print("MODEL:")
print(model.get_weights())
print()
print()
print()
print("TRANSFERMODEL:")
print(transferModel.get_weights())
# Out:
# C:\Users\kaare\anaconda3\envs\ml\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# False
#
# MODEL:
# [array([[[[-0.35253018, -0.43299332,  0.4715134 , -0.3062122 ,
#            0.37592006,  0.58779263,  0.2917849 ,  0.11568034,
#            0.34690836, -0.09825958, -0.4028611 , -0.267723  ,
#           -0.1890012 , -0.06186682, -0.02690273, -0.02063109,
#            0.2588967 , -0.7976282 , -0.17232363,  0.2449028 ,
#           -0.16498454,  0.17128254,  0.03742797,  0.55174917,
#           -0.15484843, -0.2392773 , -0.63564056,  0.4154004 ,
#           -0.19303098, -0.87941855,  0.10969175,  0.910591  ,
#           -0.5534567 ,  0.6614401 , -0.9751473 , -0.30048317,
# ...

# %%
transferModel = UNet(pretrained_weights="augment_transfer_CHASEDB1_on_DRIVE.hdf5", input_size=(608, 576, 1))
model = UNet(pretrained_weights="small_augment_unet_CHASEDB1_named_layers.hdf5", input_size=(608, 576, 1))

print("TRANSFER:\n\n\n")
print(transferModel.get_layer(name="conv_1_1").get_weights())

print("ORIGINAL:\n\n\n")
print(model.get_layer(name="conv_1_1").get_weights())
# Out:
# TRANSFER:
#
#
#
# [array([[[[ 7.97770321e-02,  4.67120200e-01, -2.86401480e-01,
#            2.93880343e-01, -2.86737710e-01, -2.28357822e-01,
#           -3.74085933e-01, -9.49521184e-01, -4.13741678e-01,
#           -5.10925531e-01, -2.31791720e-01,  4.23042148e-01,
#            2.05853745e-01,  6.54107273e-01, -3.73877957e-02,
#            1.18616410e-02, -9.76235390e-01, -8.46540093e-01,
#            1.82655886e-01,  5.72174609e-01,  1.05272543e+00,
#            1.46680102e-01,  6.09535873e-01, -5.95443785e-01,
#           -8.22533190e-01,  3.78541142e-01,  6.86621308e-01,
#            3.58904809e-01, -6.35371953e-02,  3.10915977e-01,
#            1.93108961e-01, -5.43343067e-01, -1.44752026e-01,
#            3.14414799e-01, -3.54216456e-01, -6.57823086e-01,
#            1.45433158e-01,  1.37121424e-01, -2.23118499e-01,
#           -4.65062223e-02, -3.12191695e-01,  4.58509684e-01,
#           -8.50368023e-01,  5.70087016e-01,  6.39824510e-01,
# ...
